# %% [markdown]
# *Prepared for the course "TDPS22: Data Science Programming" at Jönköping University, Teacher: [Marcel Bollmann](mailto:marcel.bollmann@ju.se)*
#
# # Exercise 7: Data Transformation with dplyr & lubridate
#
# This notebook contains exercises on data transformation. We're following [Chapter 5 in _R for Data Science_](https://r4ds.had.co.nz/transform.html), but also jump ahead a bit and include [Chapter 16 on "dates and times"](https://r4ds.had.co.nz/dates-and-times.html).
#
# Concretely, we'll look at the five core functions for data manipulation with dplyr – `filter()`, `arrange()`, `select()`, `mutate()`, and `summarise()` –, data grouping via `group_by()`, how to use pipes to chain function calls via `%>%`, and how to work with dates, date-times, and times-of-day.
#
# ### Learning Goals
#
# - Know how to _perform data manipulation_ with dplyr.
# - Understand how to _use pipes_.
# - Understand how to _work with dates and date-times_ in lubridate, and _time-of-day_ in hms.
#
# ### Useful Resources
#
# + ["Data transformation" in _R for Data Science_](https://r4ds.had.co.nz/transform.html)
# + ["Dates and times" in _R for Data Science_](https://r4ds.had.co.nz/dates-and-times.html)
# + [RStudio Cheatsheets](https://www.rstudio.com/resources/cheatsheets/)
# + [Hands-On Programming with R](https://rstudio-education.github.io/hopr/) _(as a reference)_

# %%
library(tidyverse)
library(lubridate)  # this is part of Tidyverse, but needs to be loaded explicitly
library(hms)        # this is part of Tidyverse, but needs to be loaded explicitly
# Out:
# Warning message:
# “replacing previous import ‘lifecycle::last_warnings’ by ‘rlang::last_warnings’ when loading ‘tibble’”
# Warning message:
# “replacing previous import ‘lifecycle::last_warnings’ by ‘rlang::last_warnings’ when loading ‘hms’”
# ── Attaching packages ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.4     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   2.0.1     ✔ forcats 0.5.1
#
# ── Conflicts ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘lubridate’
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union
#
#
#
# Attaching package: ‘hms’
#
#
# The following object is masked from ‘package:lubridate’:
#
#     hms

# %% [markdown]
# - - -
#
# Let's try loading the **Coffee Chain dataset** that we already saw in Exercise 1:

# %%
coffee <- read_csv("data/coffee-chain.csv")
# Out:
# Rows: 10000 Columns: 7
# ── Column specification ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): Ddate, Market, Product, Product Type
# dbl (3): Sales, Profit, Expenses
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# The column types are determined automatically, but they are not ideal — the numeric columns are assigned `dbl` (floating-point numbers) while they are actually only ever integer-valued, and the "Market", "Product", "Product Type" columns are good examples for **factors**, since they are categorical variables with a fixed set of possible values. Of course, there's also the question of how to parse the date into a proper `date` variable, but we'll get to that a little later. The other issues are easy to fix, so let's do that immediately:

# %%
coffee <- read_csv("data/coffee-chain.csv", col_types="cfffiii")
str(coffee)
# Out:
# spec_tbl_df [10,000 × 7] (S3: spec_tbl_df/tbl_df/tbl/data.frame)
#  $ Ddate       : chr [1:10000] "9/1/13" "5/1/12" "1/1/13" "8/1/12" ...
#  $ Market      : Factor w/ 4 levels "Central","East",..: 1 2 3 3 3 2 1 1 4 1 ...
#  $ Product     : Factor w/ 13 levels "Decaf Irish Cream",..: 1 2 3 4 5 6 7 1 2 1 ...
#  $ Product Type: Factor w/ 4 levels "Coffee","Espresso",..: 1 2 2 3 1 4 2 1 2 1 ...
#  $ Sales       : int [1:10000] 90 203 524 273 201 171 132 225 108 208 ...
#  $ Profit      : int [1:10000] 36 56 136 81 -3 26 72 160 37 105 ...
#  $ Expenses    : int [1:10000] 37 55 93 68 68 73 31 56 42 43 ...
#  - attr(*, "spec")=
#   .. cols(
#   ..   Ddate = col_character(),
#   ..   Market = col_factor(levels = NULL, ordered = FALSE, include_na = FALSE),
#   ..   Product = col_factor(levels = NULL, ordered = FALSE, include_na = FALSE),
#   ..   `Product Type` = col_factor(levels = NULL, ordered = FALSE, include_na = FALSE),
#   ..   Sales = col_integer(),
#   ..   Profit = col_integer(),
#   ..   Expenses = col_integer()
#   .. )
#  - attr(*, "problems")=<externalptr>

# %% [markdown]
# Look at the help for `read_csv()` if you want to know more about the `col_types` argument ...

# %% [markdown]
# - - -
#
# ## Filtering, arranging, selecting, mutating
#
# We first look at using four core dplyr functions individually:
# - `filter()` is a way to select certain _rows_ of a dataset;
# - `arrange()` is a way to sort them;
# - `select()` is a way to select certain _columns_ of a dataset; and
# - `mutate()` is a way to create new columns from old ones.
#
# **1. Select all rows with products of type "Coffee"!**  _(You should end up with 3383 rows. Look at the first line of the output to see the number of rows!)_

# %%
filter(coffee, `Product Type` == "Coffee")
# Out:
#      Ddate   Market  Product           Product Type Sales Profit Expenses
# 1    9/1/13  Central Decaf Irish Cream Coffee        90    36     37
# 2    12/1/13 West    Amaretto          Coffee       201    -3     68
# 3    2/1/13  Central Decaf Irish Cream Coffee       225   160     56
# 4    9/1/13  Central Decaf Irish Cream Coffee       208   105     43
# 5    1/1/12  Central Decaf Irish Cream Coffee       316   163     64
# 6    1/1/12  South   Decaf Irish Cream Coffee       112    66     24
# 7    2/1/13  South   Decaf Irish Cream Coffee       130    68     43
# 8    1/1/12  East    Decaf Irish Cream Coffee       252    87     81
# 9    7/1/13  Central Decaf Irish Cream Coffee        70    24     22
# 10   2/1/13  South   Decaf Irish Cream Coffee        96    27     39
# 11   10/1/12 West    Decaf Irish Cream Coffee       114    16     51
# 12   2/1/13  South   Decaf Irish Cream Coffee        82    36     23
# 13   2/1/12  West    Decaf Irish Cream Coffee       109     6     55
# 14   12/1/12 Central Decaf Irish Cream Coffee       111    13     37
# 15   12/1/12 Central Decaf Irish Cream Coffee       115    12     39
# 16   10/1/12 West    Decaf Irish Cream Coffee       134    33     58
# 17   6/1/13  East    Decaf Irish Cream Coffee       598   385    118
# 18   7/1/12  West    Decaf Irish Cream Coffee       148    43     64
# 19   4/1/12  East    Decaf Irish Cream Coffee       199    40     45
# 20   5/1/13  South   Decaf Irish Cream Coffee        76    37     21
# 21   10/1/12 South   Decaf Irish Cream Coffee        98    17     21
# 22   5/1/13  West    Decaf Irish Cream Coffee       164    46     48
# 23   8/1/13  Central Decaf Irish Cream Coffee       350   214    105
# 24   1/1/13  East    Decaf Irish Cream Coffee       342   113     57
# 25   7/1/12  West    Decaf Irish Cream Coffee       127     6     50
# 26   5/1/13  West    Colombian         Coffee       468   214     94
# 27   5/1/12  West    Amaretto          Coffee       115     1     55
# 28   5/1/12  Central Amaretto          Coffee       166    32     40
# 29   1/1/12  Central Decaf Irish Cream Coffee       191    93     42
# 30   2/1/13  West    Decaf Irish Cream Coffee        85    39     44
# ⋮    ⋮       ⋮       ⋮                 ⋮            ⋮     ⋮      ⋮
# 3354 1/1/12  Central Decaf Irish Cream Coffee       171   139     97
# 3355 1/1/12  Central Decaf Irish Cream Coffee       239   131     90
# 3356 9/1/12  Central Decaf Irish Cream Coffee        84    26     50
# 3357 5/1/12  West    Decaf Irish Cream Coffee       114    22     38
# 3358 10/1/12 Central Decaf Irish Cream Coffee       188    35     58
# 3359 3/1/13  East    Decaf Irish Cream Coffee       229    25    104
# 3360 5/1/13  Central Decaf Irish Cream Coffee       149    49     36
# 3361 2/1/12  South   Decaf Irish Cream Coffee        50    26     25
# 3362 1/1/12  Central Decaf Irish Cream Coffee       240    86     63
# 3363 5/1/13  South   Decaf Irish Cream Coffee       117    43     40
# 3364 4/1/13  West    Decaf Irish Cream Coffee       123    44     39
# 3365 11/1/13 South   Decaf Irish Cream Coffee       523   230     95
# 3366 7/1/12  South   Decaf Irish Cream Coffee       141    10     63
# 3367 8/1/13  South   Decaf Irish Cream Coffee       104     8     31
# 3368 7/1/12  Central Decaf Irish Cream Coffee       140    20     49
# 3369 8/1/12  West    Decaf Irish Cream Coffee       244    30    166
# 3370 5/1/13  West    Amaretto          Coffee       119    36     79
# 3371 12/1/12 East    Decaf Irish Cream Coffee       554   273    142
# 3372 5/1/13  Central Decaf Irish Cream Coffee       132    51     42
# 3373 5/1/13  Central Decaf Irish Cream Coffee        61    29     18
# 3374 11/1/13 Central Decaf Irish Cream Coffee       536   388    103
# 3375 10/1/12 East    Amaretto          Coffee       262    12     64
# 3376 5/1/13  West    Decaf Irish Cream Coffee       125    31     43
# 3377 12/1/12 Central Decaf Irish Cream Coffee       189    34     44
# 3378 9/1/13  West    Decaf Irish Cream Coffee       139    28     41
# 3379 9/1/13  East    Decaf Irish Cream Coffee       307   125     41
# 3380 5/1/13  West    Decaf Irish Cream Coffee       180    40     45
# 3381 2/1/12  West    Amaretto          Coffee       124    24     51
# 3382 3/1/12  Central Decaf Irish Cream Coffee       104    20     34
# 3383 1/1/12  Central Decaf Irish Cream Coffee       310   163     36

# %% [markdown]
# **2. Select all rows with negative profit values!** _(You should end up with 686 rows.)_

# %%
filter(coffee, Profit < 0)
# Out:
#     Ddate   Market  Product           Product Type Sales Profit Expenses
# 1   12/1/13 West    Amaretto          Coffee       201     -3    68
# 2   9/1/12  East    Lemon             Herbal Tea    84     -8    72
# 3   4/1/12  East    Decaf Espresso    Espresso      54     -4    26
# 4   9/1/12  South   Lemon             Herbal Tea   145     -4    54
# 5   9/1/12  South   Lemon             Herbal Tea    89     -5    37
# 6   7/1/12  West    Decaf Irish Cream Coffee       127     -2    71
# 7   5/1/13  East    Decaf Irish Cream Coffee       185    -56    49
# 8   5/1/13  West    Mint              Herbal Tea   109     -7    71
# 9   9/1/12  South   Decaf Irish Cream Coffee        77    -16    72
# 10  10/1/12 East    Darjeeling        Tea           83     -5    38
# 11  5/1/13  Central Mint              Herbal Tea   100     -8    44
# 12  10/1/12 Central Caffe Mocha       Espresso     125    -16    61
# 13  10/1/12 South   Decaf Irish Cream Coffee        52     -3    29
# 14  10/1/12 East    Caffe Mocha       Espresso      89     -2    49
# 15  8/1/13  Central Chamomile         Herbal Tea    59     -3    23
# 16  3/1/12  West    Darjeeling        Tea           96    -14    25
# 17  9/1/12  West    Amaretto          Coffee       131    -10    58
# 18  4/1/12  West    Darjeeling        Tea           84     -9    50
# 19  8/1/12  West    Decaf Irish Cream Coffee       238     -2   152
# 20  10/1/12 West    Darjeeling        Tea          146     -3    67
# 21  5/1/13  West    Darjeeling        Tea           61    -17    70
# 22  4/1/12  East    Lemon             Herbal Tea    93    -11    41
# 23  2/1/12  South   Caffe Mocha       Espresso     178     -4    83
# 24  5/1/13  West    Darjeeling        Tea           47   -521    42
# 25  8/1/12  West    Lemon             Herbal Tea    28     -4    11
# 26  7/1/12  Central Decaf Irish Cream Coffee       124     -2    52
# 27  4/1/12  East    Mint              Herbal Tea   117     -8    54
# 28  1/1/13  South   Caffe Latte       Espresso     158     -2    57
# 29  5/1/13  East    Chamomile         Herbal Tea    89    -25    67
# 30  10/1/12 West    Darjeeling        Tea           95     -3    41
# ⋮   ⋮       ⋮       ⋮                 ⋮            ⋮     ⋮      ⋮
# 657 3/1/12  Central Decaf Irish Cream Coffee       153    -26    78
# 658 7/1/12  Central Decaf Irish Cream Coffee       123     -1    48
# 659 11/1/13 East    Darjeeling        Tea           64     -5    34
# 660 9/1/12  Central Chamomile         Herbal Tea    99     -6    42
# 661 2/1/13  West    Decaf Irish Cream Coffee        84    -16    44
# 662 12/1/12 West    Decaf Irish Cream Coffee       198   -162   132
# 663 6/1/12  East    Regular Espresso  Espresso      92    -14    90
# 664 1/1/12  Central Decaf Irish Cream Coffee       118     -4    63
# 665 6/1/12  West    Decaf Irish Cream Coffee       123     -5    45
# 666 11/1/12 East    Lemon             Herbal Tea    76     -6    43
# 667 2/1/12  Central Darjeeling        Tea          122     -4    37
# 668 3/1/12  Central Decaf Irish Cream Coffee       101     -1    37
# 669 3/1/12  East    Lemon             Herbal Tea   112    -29    58
# 670 4/1/12  West    Decaf Irish Cream Coffee        72    -16    43
# 671 4/1/12  West    Darjeeling        Tea           89     -8    45
# 672 10/1/12 South   Chamomile         Herbal Tea    48    -11    21
# 673 2/1/12  West    Darjeeling        Tea          100    -14    79
# 674 11/1/12 East    Darjeeling        Tea           59     -5    22
# 675 12/1/12 Central Amaretto          Coffee       166     -5    66
# 676 3/1/12  South   Decaf Irish Cream Coffee       122     -1    78
# 677 3/1/12  East    Lemon             Herbal Tea   130    -14    78
# 678 10/1/12 West    Decaf Espresso    Espresso      67    -15    15
# 679 2/1/13  West    Decaf Irish Cream Coffee        83     -3    25
# 680 4/1/12  West    Darjeeling        Tea          101   -253   106
# 681 3/1/13  West    Decaf Irish Cream Coffee       150     -3   101
# 682 7/1/13  East    Caffe Mocha       Espresso      54    -16    27
# 683 10/1/12 East    Decaf Espresso    Espresso      54     -2    17
# 684 2/1/12  West    Darjeeling        Tea          137    -11    76
# 685 2/1/12  Central Lemon             Herbal Tea   143     -9    73
# 686 2/1/12  West    Caffe Mocha       Espresso      55   -208    23

# %% [markdown]
# **3. Select all rows with product type "Coffee" _or_ "Espresso" that also come from the "West" market!** _(You should end up with 1712 rows.)_

# %%
filter(coffee, Market == "West", `Product Type` %in% c("Coffee", "Espresso"))
# Out:
#      Ddate   Market Product           Product Type Sales Profit Expenses
# 1    1/1/13  West   Caffe Latte       Espresso     524   136     93
# 2    12/1/13 West   Amaretto          Coffee       201    -3     68
# 3    10/1/12 West   Decaf Irish Cream Coffee       114    16     51
# 4    2/1/12  West   Decaf Irish Cream Coffee       109     6     55
# 5    10/1/12 West   Decaf Irish Cream Coffee       134    33     58
# 6    7/1/12  West   Decaf Irish Cream Coffee       148    43     64
# 7    2/1/12  West   Decaf Espresso    Espresso     105    30     25
# 8    12/1/12 West   Caffe Mocha       Espresso     200    53     52
# 9    5/1/13  West   Decaf Irish Cream Coffee       164    46     48
# 10   4/1/13  West   Caffe Mocha       Espresso     198    61     45
# 11   6/1/13  West   Caffe Latte       Espresso     467   235     90
# 12   7/1/12  West   Decaf Irish Cream Coffee       127     6     50
# 13   5/1/13  West   Colombian         Coffee       468   214     94
# 14   5/1/12  West   Amaretto          Coffee       115     1     55
# 15   12/1/12 West   Caffe Mocha       Espresso      63     4     19
# 16   2/1/13  West   Decaf Irish Cream Coffee        85    39     44
# 17   2/1/12  West   Caffe Mocha       Espresso     182    68     58
# 18   11/1/12 West   Caffe Mocha       Espresso      90    24     22
# 19   5/1/12  West   Decaf Espresso    Espresso     288   120     63
# 20   1/1/13  West   Decaf Espresso    Espresso     500   130     87
# 21   4/1/12  West   Caffe Mocha       Espresso     103    23     46
# 22   7/1/12  West   Decaf Irish Cream Coffee       127    -2     71
# 23   5/1/13  West   Decaf Irish Cream Coffee        52    44     15
# 24   6/1/12  West   Decaf Irish Cream Coffee       106    46     50
# 25   1/1/13  West   Decaf Espresso    Espresso     120    63     41
# 26   6/1/12  West   Decaf Irish Cream Coffee       132    61     50
# 27   5/1/12  West   Decaf Espresso    Espresso      96    25     22
# 28   12/1/13 West   Decaf Espresso    Espresso      77    32     34
# 29   9/1/13  West   Decaf Irish Cream Coffee       130    46     39
# 30   8/1/12  West   Caffe Mocha       Espresso     516   105    108
# ⋮    ⋮       ⋮      ⋮                 ⋮            ⋮     ⋮      ⋮
# 1683 1/1/13  West   Decaf Espresso    Espresso     248    121    97
# 1684 5/1/13  West   Decaf Irish Cream Coffee        85     53    17
# 1685 6/1/12  West   Decaf Irish Cream Coffee       174     72    53
# 1686 4/1/12  West   Decaf Espresso    Espresso     174    102    38
# 1687 1/1/13  West   Decaf Irish Cream Coffee       296    137   156
# 1688 10/1/12 West   Decaf Espresso    Espresso      67    -15    15
# 1689 1/1/12  West   Decaf Espresso    Espresso      73     25    20
# 1690 2/1/13  West   Decaf Irish Cream Coffee        83     -3    25
# 1691 3/1/13  West   Decaf Irish Cream Coffee       150     -3   101
# 1692 2/1/13  West   Decaf Espresso    Espresso     131     59    35
# 1693 8/1/12  West   Decaf Irish Cream Coffee        59     15    21
# 1694 8/1/12  West   Decaf Irish Cream Coffee       174     42    67
# 1695 10/1/13 West   Decaf Espresso    Espresso     217     97    45
# 1696 4/1/13  West   Decaf Espresso    Espresso      92     51    21
# 1697 8/1/12  West   Decaf Irish Cream Coffee       165     42    45
# 1698 9/1/13  West   Decaf Espresso    Espresso     138     42    35
# 1699 4/1/12  West   Caffe Mocha       Espresso      75      8    75
# 1700 5/1/12  West   Decaf Irish Cream Coffee       114     22    38
# 1701 9/1/13  West   Decaf Espresso    Espresso     123     51    35
# 1702 4/1/13  West   Decaf Irish Cream Coffee       123     44    39
# 1703 10/1/13 West   Decaf Espresso    Espresso     327    129   109
# 1704 2/1/12  West   Caffe Mocha       Espresso      55   -208    23
# 1705 8/1/12  West   Decaf Irish Cream Coffee       244     30   166
# 1706 5/1/13  West   Amaretto          Coffee       119     36    79
# 1707 5/1/13  West   Decaf Irish Cream Coffee       125     31    43
# 1708 9/1/13  West   Decaf Irish Cream Coffee       139     28    41
# 1709 8/1/13  West   Caffe Mocha       Espresso      78     19    29
# 1710 5/1/13  West   Decaf Irish Cream Coffee       180     40    45
# 1711 2/1/12  West   Amaretto          Coffee       124     24    51
# 1712 5/1/12  West   Caffe Mocha       Espresso      99     24    49

# %% [markdown]
# **4. Select all rows with "Darjeeling" tea where the _sales_ are greater than 500!** _(You should end up with 76 rows.)_

# %%
filter(coffee, Product == "Darjeeling", Sales > 500)
# Out:
#    Ddate   Market  Product    Product Type Sales Profit Expenses
# 1  10/1/13 Central Darjeeling Tea          546   157    121
# 2  10/1/13 Central Darjeeling Tea          543   132     89
# 3  6/1/13  West    Darjeeling Tea          537   220    104
# 4  10/1/13 West    Darjeeling Tea          510   153     93
# 5  10/1/13 West    Darjeeling Tea          509   210    120
# 6  7/1/13  West    Darjeeling Tea          593   238    123
# 7  6/1/13  Central Darjeeling Tea          585   148    115
# 8  10/1/13 Central Darjeeling Tea          516   133    115
# 9  10/1/13 West    Darjeeling Tea          610   224    129
# 10 10/1/12 Central Darjeeling Tea          509   157    116
# 11 5/1/13  West    Darjeeling Tea          564   192    101
# 12 8/1/12  West    Darjeeling Tea          615   113    134
# 13 11/1/13 West    Darjeeling Tea          528   166    118
# 14 8/1/12  Central Darjeeling Tea          539   220     98
# 15 10/1/13 West    Darjeeling Tea          538   170    123
# 16 10/1/13 Central Darjeeling Tea          568   151    115
# 17 10/1/13 West    Darjeeling Tea          578   194    126
# 18 7/1/12  West    Darjeeling Tea          578   197    138
# 19 8/1/12  West    Darjeeling Tea          668   154    137
# 20 8/1/12  Central Darjeeling Tea          617   270    146
# 21 8/1/12  West    Darjeeling Tea          609   171    125
# 22 8/1/13  Central Darjeeling Tea          503   184     92
# 23 6/1/12  West    Darjeeling Tea          527   175     67
# 24 8/1/12  West    Darjeeling Tea          631   167    129
# 25 5/1/13  West    Darjeeling Tea          544   176     95
# 26 7/1/12  West    Darjeeling Tea          570   141     68
# 27 2/1/13  West    Darjeeling Tea          551   178     97
# 28 8/1/13  Central Darjeeling Tea          517   176    115
# 29 10/1/13 Central Darjeeling Tea          576   165    132
# 30 10/1/12 Central Darjeeling Tea          514   115     92
# ⋮  ⋮       ⋮       ⋮          ⋮            ⋮     ⋮      ⋮
# 47 8/1/12  West    Darjeeling Tea          639   221     70
# 48 6/1/12  Central Darjeeling Tea          527   202     43
# 49 10/1/12 West    Darjeeling Tea          504   156     89
# 50 8/1/12  Central Darjeeling Tea          536   193     91
# 51 10/1/13 Central Darjeeling Tea          535   198    107
# 52 10/1/12 Central Darjeeling Tea          535   144     91
# 53 5/1/13  Central Darjeeling Tea          543   147     98
# 54 10/1/13 West    Darjeeling Tea          641   232    115
# 55 7/1/12  West    Darjeeling Tea          590   269     95
# 56 5/1/13  West    Darjeeling Tea          591   226    118
# 57 5/1/12  West    Darjeeling Tea          544   142     87
# 58 11/1/13 Central Darjeeling Tea          508   152     91
# 59 8/1/12  West    Darjeeling Tea          622   229    155
# 60 8/1/13  West    Darjeeling Tea          540   179    116
# 61 10/1/13 West    Darjeeling Tea          510   134     87
# 62 10/1/12 West    Darjeeling Tea          547   140    110
# 63 10/1/12 Central Darjeeling Tea          512   177     52
# 64 10/1/13 West    Darjeeling Tea          626   138    113
# 65 8/1/13  Central Darjeeling Tea          515   173    115
# 66 6/1/13  West    Darjeeling Tea          553   250    128
# 67 5/1/12  West    Darjeeling Tea          535   166     93
# 68 8/1/13  Central Darjeeling Tea          692   217     93
# 69 8/1/13  West    Darjeeling Tea          589   181     71
# 70 8/1/13  Central Darjeeling Tea          654   180    130
# 71 6/1/12  West    Darjeeling Tea          505   197    113
# 72 10/1/13 West    Darjeeling Tea          509   124     97
# 73 10/1/13 West    Darjeeling Tea          619   162    110
# 74 7/1/13  West    Darjeeling Tea          574   283    125
# 75 8/1/13  West    Darjeeling Tea          506   194    112
# 76 5/1/12  West    Darjeeling Tea          524   150     89

# %% [markdown]
# **5. Arrange the coffee dataset by "Sales" in descending order!** What product had the highest number of sales in the dataset?

# %%
arrange(coffee, desc(Sales))
# Out:
#       Ddate   Market  Product           Product Type Sales Profit Expenses
# 1     8/1/12  West    Lemon             Herbal Tea   902   228    178
# 2     8/1/13  East    Lemon             Herbal Tea   806   368     95
# 3     8/1/13  West    Chamomile         Herbal Tea   791   432    137
# 4     3/1/13  East    Decaf Irish Cream Coffee       781   276    159
# 5     7/1/12  East    Decaf Irish Cream Coffee       754   256    188
# 6     7/1/12  West    Colombian         Coffee       750   190    160
# 7     8/1/12  West    Lemon             Herbal Tea   737   234    156
# 8     8/1/13  Central Colombian         Coffee       726   317    100
# 9     3/1/13  East    Decaf Irish Cream Coffee       723   476    138
# 10    10/1/13 East    Colombian         Coffee       718   303     99
# 11    8/1/12  South   Decaf Irish Cream Coffee       716   192    162
# 12    10/1/13 East    Decaf Irish Cream Coffee       709   189     97
# 13    7/1/12  West    Decaf Irish Cream Coffee       708   170     64
# 14    8/1/13  East    Decaf Irish Cream Coffee       708   362    136
# 15    3/1/13  East    Lemon             Herbal Tea   707   213    120
# 16    3/1/13  Central Chamomile         Herbal Tea   706   215    112
# 17    10/1/13 East    Decaf Irish Cream Coffee       703   294    117
# 18    3/1/13  East    Decaf Irish Cream Coffee       696   229    102
# 19    8/1/13  Central Darjeeling        Tea          692   217     93
# 20    8/1/13  East    Decaf Irish Cream Coffee       689   404    149
# 21    8/1/13  East    Decaf Irish Cream Coffee       687   529    119
# 22    10/1/13 West    Darjeeling        Tea          686   237     99
# 23    10/1/13 East    Lemon             Herbal Tea   685   226    118
# 24    9/1/13  West    Chamomile         Herbal Tea   683   383     99
# 25    3/1/13  Central Colombian         Coffee       682   139    127
# 26    7/1/13  West    Caffe Mocha       Espresso     682   245    144
# 27    7/1/12  East    Decaf Irish Cream Coffee       681   322    168
# 28    10/1/13 East    Decaf Irish Cream Coffee       680   559    144
# 29    8/1/13  East    Decaf Irish Cream Coffee       680   597    137
# 30    12/1/13 East    Colombian         Coffee       679   296    141
# ⋮     ⋮       ⋮       ⋮                 ⋮            ⋮     ⋮      ⋮
# 9971  8/1/12  Central Decaf Irish Cream Coffee       29      17    18
# 9972  10/1/12 East    Darjeeling        Tea          29      10    17
# 9973  8/1/12  West    Lemon             Herbal Tea   28      -4    11
# 9974  5/1/13  West    Decaf Espresso    Espresso     28      30    20
# 9975  8/1/12  Central Lemon             Herbal Tea   28       0    14
# 9976  8/1/12  West    Darjeeling        Tea          28       9    19
# 9977  4/1/13  East    Decaf Espresso    Espresso     28      58    20
# 9978  8/1/12  West    Caffe Mocha       Espresso     27      15    22
# 9979  10/1/12 Central Decaf Espresso    Espresso     27      -3    14
# 9980  10/1/12 Central Lemon             Herbal Tea   27      16    22
# 9981  5/1/13  West    Darjeeling        Tea          27     -12    51
# 9982  11/1/12 West    Decaf Irish Cream Coffee       26       3    29
# 9983  8/1/12  West    Darjeeling        Tea          25    -407   110
# 9984  10/1/13 West    Earl Grey         Tea          25     -30    95
# 9985  11/1/12 West    Decaf Espresso    Espresso     24      20    17
# 9986  11/1/12 West    Caffe Latte       Espresso     24      21    23
# 9987  5/1/13  Central Decaf Irish Cream Coffee       23      35    16
# 9988  5/1/13  Central Decaf Irish Cream Coffee       23      24    17
# 9989  12/1/12 West    Caffe Mocha       Espresso     23       2    20
# 9990  8/1/13  Central Chamomile         Herbal Tea   23      14    19
# 9991  10/1/13 West    Chamomile         Herbal Tea   22      21    17
# 9992  7/1/13  Central Decaf Espresso    Espresso     22      20    17
# 9993  8/1/13  East    Darjeeling        Tea          21      -3    19
# 9994  1/1/13  South   Caffe Mocha       Espresso     20      23    15
# 9995  11/1/12 East    Chamomile         Herbal Tea   20       0    21
# 9996  11/1/12 Central Caffe Mocha       Espresso     18      10    20
# 9997  11/1/12 West    Caffe Mocha       Espresso     17      17    19
# 9998  8/1/13  East    Darjeeling        Tea          17       2    20
# 9999  8/1/13  East    Decaf Espresso    Espresso     17       0    10
# 10000 8/1/13  West    Darjeeling        Tea          17     -15    37

# %% [markdown]
# **6. Select the "Product" and "Product Type" columns and assign them to a variable `products`!**

# %%
products <- select(coffee, contains("Product"))

# %% [markdown]
# Afterwards, you should be able to run the following line of code to get all 13 unique "Product"–"Product Type" combinations:

# %%
unique(products)
# Out:
#    Product           Product Type
# 1  Decaf Irish Cream Coffee
# 2  Decaf Espresso    Espresso
# 3  Caffe Latte       Espresso
# 4  Earl Grey         Tea
# 5  Amaretto          Coffee
# 6  Lemon             Herbal Tea
# 7  Caffe Mocha       Espresso
# 8  Mint              Herbal Tea
# 9  Darjeeling        Tea
# 10 Chamomile         Herbal Tea
# 11 Green Tea         Tea
# 12 Colombian         Coffee
# 13 Regular Espresso  Espresso

# %% [markdown]
# **7. Find out what the `any_of()` function does, and how to use it to select all columns whose names are included in the `cols` vector below.**

# %%
cols <- c("Sales", "Inventory", "Budget", "Profit", "Expenses")

# %%
select(coffee, any_of(cols))
# Out:
#       Sales Profit Expenses
# 1      90    36    37
# 2     203    56    55
# 3     524   136    93
# 4     273    81    68
# 5     201    -3    68
# 6     171    26    73
# 7     132    72    31
# 8     225   160    56
# 9     108    37    42
# 10    208   105    43
# 11    117    46    22
# 12    214    48    59
# 13    316   163    64
# 14    112    66    24
# 15    130    68    43
# 16     84    -8    72
# 17    252    87    81
# 18     49    23    17
# 19     67    18    17
# 20     70    24    22
# 21    114    41    43
# 22    100     2    40
# 23    208    99    34
# 24    227   112    50
# 25     96    27    39
# 26    114    16    51
# 27     82    36    23
# 28    233    75    56
# 29    109     6    55
# 30    111    13    37
# ⋮     ⋮     ⋮      ⋮
# 9971  259   103     45
# 9972  215    81     59
# 9973  100    12     33
# 9974   75    45     35
# 9975  132    51     42
# 9976   61    29     18
# 9977  536   388    103
# 9978   74    20     20
# 9979  124    65     32
# 9980  262    12     64
# 9981   71     3     11
# 9982  125    31     43
# 9983  189    34     44
# 9984  139    28     41
# 9985   78    19     29
# 9986  307   125     41
# 9987  149    54     48
# 9988  180    40     45
# 9989   91    21     28
# 9990  124    24     51
# 9991   62    28     24
# 9992   99    24     49
# 9993  104    20     34
# 9994  504   291    127
# 9995  310   163     36
# 9996  185    59     39
# 9997   88    17     36
# 9998   61    21     21
# 9999  124    38     84
# 10000 524   150     89

# %% [markdown]
# **8. Rearrange the columns so that the "Product Type" column comes first.**

# %%
select(coffee, `Product Type`, everything())
# Out:
#       Product Type Ddate   Market  Product           Sales Profit Expenses
# 1     Coffee       9/1/13  Central Decaf Irish Cream  90    36    37
# 2     Espresso     5/1/12  East    Decaf Espresso    203    56    55
# 3     Espresso     1/1/13  West    Caffe Latte       524   136    93
# 4     Tea          8/1/12  West    Earl Grey         273    81    68
# 5     Coffee       12/1/13 West    Amaretto          201    -3    68
# 6     Herbal Tea   9/1/12  East    Lemon             171    26    73
# 7     Espresso     9/1/13  Central Caffe Mocha       132    72    31
# 8     Coffee       2/1/13  Central Decaf Irish Cream 225   160    56
# 9     Espresso     10/1/12 South   Decaf Espresso    108    37    42
# 10    Coffee       9/1/13  Central Decaf Irish Cream 208   105    43
# 11    Espresso     2/1/12  South   Caffe Latte       117    46    22
# 12    Herbal Tea   5/1/12  East    Lemon             214    48    59
# 13    Coffee       1/1/12  Central Decaf Irish Cream 316   163    64
# 14    Coffee       1/1/12  South   Decaf Irish Cream 112    66    24
# 15    Coffee       2/1/13  South   Decaf Irish Cream 130    68    43
# 16    Herbal Tea   9/1/12  East    Lemon              84    -8    72
# 17    Coffee       1/1/12  East    Decaf Irish Cream 252    87    81
# 18    Espresso     8/1/12  South   Caffe Mocha        49    23    17
# 19    Herbal Tea   10/1/13 Central Lemon              67    18    17
# 20    Coffee       7/1/13  Central Decaf Irish Cream  70    24    22
# 21    Herbal Tea   5/1/13  Central Lemon             114    41    43
# 22    Herbal Tea   10/1/12 East    Mint              100     2    40
# 23    Tea          2/1/12  Central Darjeeling        208    99    34
# 24    Herbal Tea   9/1/13  East    Lemon             227   112    50
# 25    Coffee       2/1/13  South   Decaf Irish Cream  96    27    39
# 26    Coffee       10/1/12 West    Decaf Irish Cream 114    16    51
# 27    Coffee       2/1/13  South   Decaf Irish Cream  82    36    23
# 28    Herbal Tea   7/1/12  West    Lemon             233    75    56
# 29    Coffee       2/1/12  West    Decaf Irish Cream 109     6    55
# 30    Coffee       12/1/12 Central Decaf Irish Cream 111    13    37
# ⋮     ⋮            ⋮       ⋮       ⋮                 ⋮     ⋮      ⋮
# 9971  Tea          5/1/12  Central Earl Grey         259   103     45
# 9972  Espresso     10/1/12 South   Caffe Mocha       215    81     59
# 9973  Espresso     6/1/13  East    Decaf Espresso    100    12     33
# 9974  Tea          9/1/13  East    Darjeeling         75    45     35
# 9975  Coffee       5/1/13  Central Decaf Irish Cream 132    51     42
# 9976  Coffee       5/1/13  Central Decaf Irish Cream  61    29     18
# 9977  Coffee       11/1/13 Central Decaf Irish Cream 536   388    103
# 9978  Herbal Tea   8/1/13  East    Chamomile          74    20     20
# 9979  Espresso     2/1/13  East    Decaf Espresso    124    65     32
# 9980  Coffee       10/1/12 East    Amaretto          262    12     64
# 9981  Herbal Tea   8/1/13  West    Chamomile          71     3     11
# 9982  Coffee       5/1/13  West    Decaf Irish Cream 125    31     43
# 9983  Coffee       12/1/12 Central Decaf Irish Cream 189    34     44
# 9984  Coffee       9/1/13  West    Decaf Irish Cream 139    28     41
# 9985  Espresso     8/1/13  West    Caffe Mocha        78    19     29
# 9986  Coffee       9/1/13  East    Decaf Irish Cream 307   125     41
# 9987  Herbal Tea   1/1/13  East    Mint              149    54     48
# 9988  Coffee       5/1/13  West    Decaf Irish Cream 180    40     45
# 9989  Espresso     11/1/12 South   Caffe Latte        91    21     28
# 9990  Coffee       2/1/12  West    Amaretto          124    24     51
# 9991  Espresso     11/1/12 East    Regular Espresso   62    28     24
# 9992  Espresso     5/1/12  West    Caffe Mocha        99    24     49
# 9993  Coffee       3/1/12  Central Decaf Irish Cream 104    20     34
# 9994  Herbal Tea   5/1/13  West    Lemon             504   291    127
# 9995  Coffee       1/1/12  Central Decaf Irish Cream 310   163     36
# 9996  Tea          2/1/12  Central Darjeeling        185    59     39
# 9997  Tea          3/1/12  East    Darjeeling         88    17     36
# 9998  Herbal Tea   8/1/13  Central Chamomile          61    21     21
# 9999  Espresso     4/1/12  East    Caffe Mocha       124    38     84
# 10000 Tea          5/1/12  West    Darjeeling        524   150     89

# %% [markdown]
# **9. Rename the "Product Type" column to "Product_Type"!** Notice the underscore. If we change the space to an underscore, we don't have to wrap this column name in backticks all the time. Assign the result to the `coffee` variable again so the change persists!

# %%
coffee <- rename(coffee, Product_Type = `Product Type`)

# %% [markdown]
# _Bonus:_ The `rename_with()` function changes column names based on a function. For example, we can change them all to lowercase via:

# %%
coffee <- rename_with(coffee, tolower)

# %% [markdown]
# I'll refer to column names in lowercase from here on.

# %% [markdown]
# **10. Create two new columns: a column "revenue" that is the _sum_ of "profit" and "expenses"; and a column "margin" that is "profit" _divided by_ "revenue".** Try to create both columns in a single `mutate()` statement.

# %%
(coffee <- mutate(coffee, revenue = profit + expenses, margin = profit / revenue))
# Out:
#       ddate   market  product           product_type sales profit expenses
# 1     9/1/13  Central Decaf Irish Cream Coffee        90    36    37
# 2     5/1/12  East    Decaf Espresso    Espresso     203    56    55
# 3     1/1/13  West    Caffe Latte       Espresso     524   136    93
# 4     8/1/12  West    Earl Grey         Tea          273    81    68
# 5     12/1/13 West    Amaretto          Coffee       201    -3    68
# 6     9/1/12  East    Lemon             Herbal Tea   171    26    73
# 7     9/1/13  Central Caffe Mocha       Espresso     132    72    31
# 8     2/1/13  Central Decaf Irish Cream Coffee       225   160    56
# 9     10/1/12 South   Decaf Espresso    Espresso     108    37    42
# 10    9/1/13  Central Decaf Irish Cream Coffee       208   105    43
# 11    2/1/12  South   Caffe Latte       Espresso     117    46    22
# 12    5/1/12  East    Lemon             Herbal Tea   214    48    59
# 13    1/1/12  Central Decaf Irish Cream Coffee       316   163    64
# 14    1/1/12  South   Decaf Irish Cream Coffee       112    66    24
# 15    2/1/13  South   Decaf Irish Cream Coffee       130    68    43
# 16    9/1/12  East    Lemon             Herbal Tea    84    -8    72
# 17    1/1/12  East    Decaf Irish Cream Coffee       252    87    81
# 18    8/1/12  South   Caffe Mocha       Espresso      49    23    17
# 19    10/1/13 Central Lemon             Herbal Tea    67    18    17
# 20    7/1/13  Central Decaf Irish Cream Coffee        70    24    22
# 21    5/1/13  Central Lemon             Herbal Tea   114    41    43
# 22    10/1/12 East    Mint              Herbal Tea   100     2    40
# 23    2/1/12  Central Darjeeling        Tea          208    99    34
# 24    9/1/13  East    Lemon             Herbal Tea   227   112    50
# 25    2/1/13  South   Decaf Irish Cream Coffee        96    27    39
# 26    10/1/12 West    Decaf Irish Cream Coffee       114    16    51
# 27    2/1/13  South   Decaf Irish Cream Coffee        82    36    23
# 28    7/1/12  West    Lemon             Herbal Tea   233    75    56
# 29    2/1/12  West    Decaf Irish Cream Coffee       109     6    55
# 30    12/1/12 Central Decaf Irish Cream Coffee       111    13    37
# ⋮     ⋮       ⋮       ⋮                 ⋮            ⋮     ⋮      ⋮
# 9971  5/1/12  Central Earl Grey         Tea          259   103     45
# 9972  10/1/12 South   Caffe Mocha       Espresso     215    81     59
# 9973  6/1/13  East    Decaf Espresso    Espresso     100    12     33
# 9974  9/1/13  East    Darjeeling        Tea           75    45     35
# 9975  5/1/13  Central Decaf Irish Cream Coffee       132    51     42
# 9976  5/1/13  Central Decaf Irish Cream Coffee        61    29     18
# 9977  11/1/13 Central Decaf Irish Cream Coffee       536   388    103
# 9978  8/1/13  East    Chamomile         Herbal Tea    74    20     20
# 9979  2/1/13  East    Decaf Espresso    Espresso     124    65     32
# 9980  10/1/12 East    Amaretto          Coffee       262    12     64
# 9981  8/1/13  West    Chamomile         Herbal Tea    71     3     11
# 9982  5/1/13  West    Decaf Irish Cream Coffee       125    31     43
# 9983  12/1/12 Central Decaf Irish Cream Coffee       189    34     44
# 9984  9/1/13  West    Decaf Irish Cream Coffee       139    28     41
# 9985  8/1/13  West    Caffe Mocha       Espresso      78    19     29
# 9986  9/1/13  East    Decaf Irish Cream Coffee       307   125     41
# 9987  1/1/13  East    Mint              Herbal Tea   149    54     48
# 9988  5/1/13  West    Decaf Irish Cream Coffee       180    40     45
# 9989  11/1/12 South   Caffe Latte       Espresso      91    21     28
# 9990  2/1/12  West    Amaretto          Coffee       124    24     51
# 9991  11/1/12 East    Regular Espresso  Espresso      62    28     24
# 9992  5/1/12  West    Caffe Mocha       Espresso      99    24     49
# 9993  3/1/12  Central Decaf Irish Cream Coffee       104    20     34
# 9994  5/1/13  West    Lemon             Herbal Tea   504   291    127
# 9995  1/1/12  Central Decaf Irish Cream Coffee       310   163     36
# 9996  2/1/12  Central Darjeeling        Tea          185    59     39
# 9997  3/1/12  East    Darjeeling        Tea           88    17     36
# 9998  8/1/13  Central Chamomile         Herbal Tea    61    21     21
# 9999  4/1/12  East    Caffe Mocha       Espresso     124    38     84
# 10000 5/1/12  West    Darjeeling        Tea          524   150     89
#       revenue margin
# 1      73      0.49315068
# 2     111      0.50450450
# 3     229      0.59388646
# 4     149      0.54362416
# 5      65     -0.04615385
# 6      99      0.26262626
# 7     103      0.69902913
# 8     216      0.74074074
# 9      79      0.46835443
# 10    148      0.70945946
# 11     68      0.67647059
# 12    107      0.44859813
# 13    227      0.71806167
# 14     90      0.73333333
# 15    111      0.61261261
# 16     64     -0.12500000
# 17    168      0.51785714
# 18     40      0.57500000
# 19     35      0.51428571
# 20     46      0.52173913
# 21     84      0.48809524
# 22     42      0.04761905
# 23    133      0.74436090
# 24    162      0.69135802
# 25     66      0.40909091
# 26     67      0.23880597
# 27     59      0.61016949
# 28    131      0.57251908
# 29     61      0.09836066
# 30     50      0.26000000
# ⋮     ⋮       ⋮
# 9971  148     0.6959459
# 9972  140     0.5785714
# 9973   45     0.2666667
# 9974   80     0.5625000
# 9975   93     0.5483871
# 9976   47     0.6170213
# 9977  491     0.7902240
# 9978   40     0.5000000
# 9979   97     0.6701031
# 9980   76     0.1578947
# 9981   14     0.2142857
# 9982   74     0.4189189
# 9983   78     0.4358974
# 9984   69     0.4057971
# 9985   48     0.3958333
# 9986  166     0.7530120
# 9987  102     0.5294118
# 9988   85     0.4705882
# 9989   49     0.4285714
# 9990   75     0.3200000
# 9991   52     0.5384615
# 9992   73     0.3287671
# 9993   54     0.3703704
# 9994  418     0.6961722
# 9995  199     0.8190955
# 9996   98     0.6020408
# 9997   53     0.3207547
# 9998   42     0.5000000
# 9999  122     0.3114754
# 10000 239     0.6276151

# %% [markdown]
# **11. Make a new column "profit_above_avg" that is `TRUE` when the "profit" is above the average of the dataset, and `FALSE` otherwise.** _Note:_ You can get the average by calling `mean()`.

# %%
(coffee <- mutate(coffee, profit_above_avg = profit > mean(profit)))
# Out:
#       ddate   market  product           product_type sales profit expenses
# 1     9/1/13  Central Decaf Irish Cream Coffee        90    36    37
# 2     5/1/12  East    Decaf Espresso    Espresso     203    56    55
# 3     1/1/13  West    Caffe Latte       Espresso     524   136    93
# 4     8/1/12  West    Earl Grey         Tea          273    81    68
# 5     12/1/13 West    Amaretto          Coffee       201    -3    68
# 6     9/1/12  East    Lemon             Herbal Tea   171    26    73
# 7     9/1/13  Central Caffe Mocha       Espresso     132    72    31
# 8     2/1/13  Central Decaf Irish Cream Coffee       225   160    56
# 9     10/1/12 South   Decaf Espresso    Espresso     108    37    42
# 10    9/1/13  Central Decaf Irish Cream Coffee       208   105    43
# 11    2/1/12  South   Caffe Latte       Espresso     117    46    22
# 12    5/1/12  East    Lemon             Herbal Tea   214    48    59
# 13    1/1/12  Central Decaf Irish Cream Coffee       316   163    64
# 14    1/1/12  South   Decaf Irish Cream Coffee       112    66    24
# 15    2/1/13  South   Decaf Irish Cream Coffee       130    68    43
# 16    9/1/12  East    Lemon             Herbal Tea    84    -8    72
# 17    1/1/12  East    Decaf Irish Cream Coffee       252    87    81
# 18    8/1/12  South   Caffe Mocha       Espresso      49    23    17
# 19    10/1/13 Central Lemon             Herbal Tea    67    18    17
# 20    7/1/13  Central Decaf Irish Cream Coffee        70    24    22
# 21    5/1/13  Central Lemon             Herbal Tea   114    41    43
# 22    10/1/12 East    Mint              Herbal Tea   100     2    40
# 23    2/1/12  Central Darjeeling        Tea          208    99    34
# 24    9/1/13  East    Lemon             Herbal Tea   227   112    50
# 25    2/1/13  South   Decaf Irish Cream Coffee        96    27    39
# 26    10/1/12 West    Decaf Irish Cream Coffee       114    16    51
# 27    2/1/13  South   Decaf Irish Cream Coffee        82    36    23
# 28    7/1/12  West    Lemon             Herbal Tea   233    75    56
# 29    2/1/12  West    Decaf Irish Cream Coffee       109     6    55
# 30    12/1/12 Central Decaf Irish Cream Coffee       111    13    37
# ⋮     ⋮       ⋮       ⋮                 ⋮            ⋮     ⋮      ⋮
# 9971  5/1/12  Central Earl Grey         Tea          259   103     45
# 9972  10/1/12 South   Caffe Mocha       Espresso     215    81     59
# 9973  6/1/13  East    Decaf Espresso    Espresso     100    12     33
# 9974  9/1/13  East    Darjeeling        Tea           75    45     35
# 9975  5/1/13  Central Decaf Irish Cream Coffee       132    51     42
# 9976  5/1/13  Central Decaf Irish Cream Coffee        61    29     18
# 9977  11/1/13 Central Decaf Irish Cream Coffee       536   388    103
# 9978  8/1/13  East    Chamomile         Herbal Tea    74    20     20
# 9979  2/1/13  East    Decaf Espresso    Espresso     124    65     32
# 9980  10/1/12 East    Amaretto          Coffee       262    12     64
# 9981  8/1/13  West    Chamomile         Herbal Tea    71     3     11
# 9982  5/1/13  West    Decaf Irish Cream Coffee       125    31     43
# 9983  12/1/12 Central Decaf Irish Cream Coffee       189    34     44
# 9984  9/1/13  West    Decaf Irish Cream Coffee       139    28     41
# 9985  8/1/13  West    Caffe Mocha       Espresso      78    19     29
# 9986  9/1/13  East    Decaf Irish Cream Coffee       307   125     41
# 9987  1/1/13  East    Mint              Herbal Tea   149    54     48
# 9988  5/1/13  West    Decaf Irish Cream Coffee       180    40     45
# 9989  11/1/12 South   Caffe Latte       Espresso      91    21     28
# 9990  2/1/12  West    Amaretto          Coffee       124    24     51
# 9991  11/1/12 East    Regular Espresso  Espresso      62    28     24
# 9992  5/1/12  West    Caffe Mocha       Espresso      99    24     49
# 9993  3/1/12  Central Decaf Irish Cream Coffee       104    20     34
# 9994  5/1/13  West    Lemon             Herbal Tea   504   291    127
# 9995  1/1/12  Central Decaf Irish Cream Coffee       310   163     36
# 9996  2/1/12  Central Darjeeling        Tea          185    59     39
# 9997  3/1/12  East    Darjeeling        Tea           88    17     36
# 9998  8/1/13  Central Chamomile         Herbal Tea    61    21     21
# 9999  4/1/12  East    Caffe Mocha       Espresso     124    38     84
# 10000 5/1/12  West    Darjeeling        Tea          524   150     89
#       revenue margin      profit_above_avg
# 1      73      0.49315068 FALSE
# 2     111      0.50450450 FALSE
# 3     229      0.59388646  TRUE
# 4     149      0.54362416  TRUE
# 5      65     -0.04615385 FALSE
# 6      99      0.26262626 FALSE
# 7     103      0.69902913  TRUE
# 8     216      0.74074074  TRUE
# 9      79      0.46835443 FALSE
# 10    148      0.70945946  TRUE
# 11     68      0.67647059 FALSE
# 12    107      0.44859813 FALSE
# 13    227      0.71806167  TRUE
# 14     90      0.73333333  TRUE
# 15    111      0.61261261  TRUE
# 16     64     -0.12500000 FALSE
# 17    168      0.51785714  TRUE
# 18     40      0.57500000 FALSE
# 19     35      0.51428571 FALSE
# 20     46      0.52173913 FALSE
# 21     84      0.48809524 FALSE
# 22     42      0.04761905 FALSE
# 23    133      0.74436090  TRUE
# 24    162      0.69135802  TRUE
# 25     66      0.40909091 FALSE
# 26     67      0.23880597 FALSE
# 27     59      0.61016949 FALSE
# 28    131      0.57251908  TRUE
# 29     61      0.09836066 FALSE
# 30     50      0.26000000 FALSE
# ⋮     ⋮       ⋮           ⋮
# 9971  148     0.6959459    TRUE
# 9972  140     0.5785714    TRUE
# 9973   45     0.2666667   FALSE
# 9974   80     0.5625000   FALSE
# 9975   93     0.5483871   FALSE
# 9976   47     0.6170213   FALSE
# 9977  491     0.7902240    TRUE
# 9978   40     0.5000000   FALSE
# 9979   97     0.6701031    TRUE
# 9980   76     0.1578947   FALSE
# 9981   14     0.2142857   FALSE
# 9982   74     0.4189189   FALSE
# 9983   78     0.4358974   FALSE
# 9984   69     0.4057971   FALSE
# 9985   48     0.3958333   FALSE
# 9986  166     0.7530120    TRUE
# 9987  102     0.5294118   FALSE
# 9988   85     0.4705882   FALSE
# 9989   49     0.4285714   FALSE
# 9990   75     0.3200000   FALSE
# 9991   52     0.5384615   FALSE
# 9992   73     0.3287671   FALSE
# 9993   54     0.3703704   FALSE
# 9994  418     0.6961722    TRUE
# 9995  199     0.8190955    TRUE
# 9996   98     0.6020408   FALSE
# 9997   53     0.3207547   FALSE
# 9998   42     0.5000000   FALSE
# 9999  122     0.3114754   FALSE
# 10000 239     0.6276151    TRUE

# %% [markdown]
# - - -
#
# ## Pipes, grouping, and summarising
#
# _Grouping_ and _summarising_ data is mainly done via `group_by()` and `summarise()`. They are often used together, and as such, it's a good idea to take a look at _pipes_ first before we get more into them.

# %% [markdown]
# **12. Rewrite the cell below to a version _without pipes_ and _only one function per line_.** Use intermediate variables to store results of function calls. Basically, make sure that you understand what exactly is happening in the pipe.

# %%
coffee %>%  
  pull(profit) %>%
  sum == 643034
# Out:
# [1] TRUE

# %%
tmp <- pull(coffee, profit)
tmp <- sum(tmp)
tmp == 643034
# Out:
# [1] TRUE

# %% [markdown]
# **13. Rewrite the cell below to a version _with pipes_.** You can use the `pull()` function to "pull out" specific columns of the dataset, or use the dot `.` in a pipe as a placeholder for the input variable.

# %%
tmp <- filter(coffee, sales > 100)
tmp <- count(tmp)
tmp$n
# Out:
# [1] 7444

# %%
coffee %>% filter(sales > 100) %>% count %>% pull(n)
# or
coffee %>% filter(sales > 100) %>% count %>% .$n
# Out:
# [1] 7444
# [1] 7444

# %% [markdown]
# **14. How many instances of each product type are there, and which one generates the most/the least profit, on average?** You'll need to chain a `group_by()` and a `summarise()` call to solve this; try to do this with a pipe (`%>%`) instead of intermediate variables, if possible. You should end up with a tibble that has four rows, one for each product type, and columns for the _name_, _count_, and _mean profit_ of each product type.

# %%
coffee %>%
  group_by(product_type) %>%
  summarise(
      count = n(),
      mean_profit = mean(profit),
  )
# Out:
#   product_type count mean_profit
# 1 Coffee       3383  75.57819
# 2 Espresso     2408  58.97301
# 3 Tea          1714  51.12602
# 4 Herbal Tea   2495  63.21283

# %% [markdown]
# **15. What's the _minimum, maximum, average, and median profit_ per "product"?** The resulting tibble should have unique "product" values (e.g., Amaretto, Caffe Latte, ...) as _rows_, and the statistics about the distribution of their "profit" values as _columns_.

# %%
coffee %>%
  group_by(product) %>%
  summarise(
      count = n(),
      min(profit),
      mean(profit),
      max(profit),
      median(profit)
  )
# Out:
#    product           count min(profit) mean(profit) max(profit) median(profit)
# 1  Decaf Irish Cream 3116  -366         71.02246    778          42.0
# 2  Decaf Espresso    1149  -301         59.00957    329          41.0
# 3  Caffe Latte        292   -27         46.11644    315          31.0
# 4  Earl Grey           79   -30         89.03797    234          86.0
# 5  Amaretto           166   -40         57.25301    371          33.0
# 6  Lemon             1143  -214         63.99825    448          37.0
# 7  Caffe Mocha        919  -321         64.00109    437          41.0
# 8  Mint               354  -289         53.99153    277          42.0
# 9  Darjeeling        1626  -586         49.45941    283          33.0
# 10 Chamomile          998  -117         65.58417    432          40.0
# 11 Green Tea            9   -18         19.44444     84          11.0
# 12 Colombian          101    31        246.24752    626         236.0
# 13 Regular Espresso    48   -33         40.04167    357          -0.5

# %% [markdown]
# **16. Filter out all products where we don't have data from all markets.** This is potentially a bit trickier. You might want to start by finding an expression that gives you the number of unique markets (you've seen an example for getting unique values at the top of this notebook, and you can look at the `length()` function to obtain a count), then try to figure out how to use grouping and filtering to achieve the desired result.
#
# _Note:_ Like in Exercise 1, where we did this before in Python, an indication that you got the right expression is that you should end up with a filtered dataset that has 7426 rows.

# %%
coffee %>%
  group_by(product) %>%
  filter(length(unique(market)) == 4)   # alternatively: n_distinct(market) == 4
# Out:
#      ddate   market  product           product_type sales profit expenses
# 1    9/1/13  Central Decaf Irish Cream Coffee        90    36     37
# 2    5/1/12  East    Decaf Espresso    Espresso     203    56     55
# 3    9/1/12  East    Lemon             Herbal Tea   171    26     73
# 4    9/1/13  Central Caffe Mocha       Espresso     132    72     31
# 5    2/1/13  Central Decaf Irish Cream Coffee       225   160     56
# 6    10/1/12 South   Decaf Espresso    Espresso     108    37     42
# 7    9/1/13  Central Decaf Irish Cream Coffee       208   105     43
# 8    5/1/12  East    Lemon             Herbal Tea   214    48     59
# 9    1/1/12  Central Decaf Irish Cream Coffee       316   163     64
# 10   1/1/12  South   Decaf Irish Cream Coffee       112    66     24
# 11   2/1/13  South   Decaf Irish Cream Coffee       130    68     43
# 12   9/1/12  East    Lemon             Herbal Tea    84    -8     72
# 13   1/1/12  East    Decaf Irish Cream Coffee       252    87     81
# 14   8/1/12  South   Caffe Mocha       Espresso      49    23     17
# 15   10/1/13 Central Lemon             Herbal Tea    67    18     17
# 16   7/1/13  Central Decaf Irish Cream Coffee        70    24     22
# 17   5/1/13  Central Lemon             Herbal Tea   114    41     43
# 18   9/1/13  East    Lemon             Herbal Tea   227   112     50
# 19   2/1/13  South   Decaf Irish Cream Coffee        96    27     39
# 20   10/1/12 West    Decaf Irish Cream Coffee       114    16     51
# 21   2/1/13  South   Decaf Irish Cream Coffee        82    36     23
# 22   7/1/12  West    Lemon             Herbal Tea   233    75     56
# 23   2/1/12  West    Decaf Irish Cream Coffee       109     6     55
# 24   12/1/12 Central Decaf Irish Cream Coffee       111    13     37
# 25   12/1/12 Central Decaf Irish Cream Coffee       115    12     39
# 26   3/1/12  South   Chamomile         Herbal Tea   105    13     38
# 27   9/1/13  East    Decaf Espresso    Espresso     228    91     50
# 28   2/1/12  West    Lemon             Herbal Tea   289   113    121
# 29   10/1/12 West    Decaf Irish Cream Coffee       134    33     58
# 30   3/1/12  East    Decaf Espresso    Espresso     207    30     50
# ⋮    ⋮       ⋮       ⋮                 ⋮            ⋮     ⋮      ⋮
# 7397 1/1/13  West    Chamomile         Herbal Tea   168     61    49
# 7398 10/1/13 West    Decaf Espresso    Espresso     327    129   109
# 7399 9/1/12  South   Lemon             Herbal Tea   146     55    46
# 7400 2/1/12  West    Caffe Mocha       Espresso      55   -208    23
# 7401 8/1/12  West    Decaf Irish Cream Coffee       244     30   166
# 7402 10/1/12 West    Chamomile         Herbal Tea   256     92    93
# 7403 2/1/12  East    Lemon             Herbal Tea   115     24    47
# 7404 9/1/13  Central Caffe Mocha       Espresso     161     38    35
# 7405 12/1/12 East    Decaf Irish Cream Coffee       554    273   142
# 7406 1/1/13  East    Chamomile         Herbal Tea   141     48    26
# 7407 10/1/12 South   Caffe Mocha       Espresso     215     81    59
# 7408 6/1/13  East    Decaf Espresso    Espresso     100     12    33
# 7409 5/1/13  Central Decaf Irish Cream Coffee       132     51    42
# 7410 5/1/13  Central Decaf Irish Cream Coffee        61     29    18
# 7411 11/1/13 Central Decaf Irish Cream Coffee       536    388   103
# 7412 8/1/13  East    Chamomile         Herbal Tea    74     20    20
# 7413 2/1/13  East    Decaf Espresso    Espresso     124     65    32
# 7414 8/1/13  West    Chamomile         Herbal Tea    71      3    11
# 7415 5/1/13  West    Decaf Irish Cream Coffee       125     31    43
# 7416 12/1/12 Central Decaf Irish Cream Coffee       189     34    44
# 7417 9/1/13  West    Decaf Irish Cream Coffee       139     28    41
# 7418 8/1/13  West    Caffe Mocha       Espresso      78     19    29
# 7419 9/1/13  East    Decaf Irish Cream Coffee       307    125    41
# 7420 5/1/13  West    Decaf Irish Cream Coffee       180     40    45
# 7421 5/1/12  West    Caffe Mocha       Espresso      99     24    49
# 7422 3/1/12  Central Decaf Irish Cream Coffee       104     20    34
# 7423 5/1/13  West    Lemon             Herbal Tea   504    291   127
# 7424 1/1/12  Central Decaf Irish Cream Coffee       310    163    36
# 7425 8/1/13  Central Chamomile         Herbal Tea    61     21    21
# 7426 4/1/12  East    Caffe Mocha       Espresso     124     38    84
#      revenue margin      profit_above_avg
# 1     73      0.49315068 FALSE
# 2    111      0.50450450 FALSE
# 3     99      0.26262626 FALSE
# 4    103      0.69902913  TRUE
# 5    216      0.74074074  TRUE
# 6     79      0.46835443 FALSE
# 7    148      0.70945946  TRUE
# 8    107      0.44859813 FALSE
# 9    227      0.71806167  TRUE
# 10    90      0.73333333  TRUE
# 11   111      0.61261261  TRUE
# 12    64     -0.12500000 FALSE
# 13   168      0.51785714  TRUE
# 14    40      0.57500000 FALSE
# 15    35      0.51428571 FALSE
# 16    46      0.52173913 FALSE
# 17    84      0.48809524 FALSE
# 18   162      0.69135802  TRUE
# 19    66      0.40909091 FALSE
# 20    67      0.23880597 FALSE
# 21    59      0.61016949 FALSE
# 22   131      0.57251908  TRUE
# 23    61      0.09836066 FALSE
# 24    50      0.26000000 FALSE
# 25    51      0.23529412 FALSE
# 26    51      0.25490196 FALSE
# 27   141      0.64539007  TRUE
# 28   234      0.48290598  TRUE
# 29    91      0.36263736 FALSE
# 30    80      0.37500000 FALSE
# ⋮    ⋮       ⋮           ⋮
# 7397  110    0.5545455   FALSE
# 7398  238    0.5420168    TRUE
# 7399  101    0.5445545   FALSE
# 7400 -185    1.1243243   FALSE
# 7401  196    0.1530612   FALSE
# 7402  185    0.4972973    TRUE
# 7403   71    0.3380282   FALSE
# 7404   73    0.5205479   FALSE
# 7405  415    0.6578313    TRUE
# 7406   74    0.6486486   FALSE
# 7407  140    0.5785714    TRUE
# 7408   45    0.2666667   FALSE
# 7409   93    0.5483871   FALSE
# 7410   47    0.6170213   FALSE
# 7411  491    0.7902240    TRUE
# 7412   40    0.5000000   FALSE
# 7413   97    0.6701031    TRUE
# 7414   14    0.2142857   FALSE
# 7415   74    0.4189189   FALSE
# 7416   78    0.4358974   FALSE
# 7417   69    0.4057971   FALSE
# 7418   48    0.3958333   FALSE
# 7419  166    0.7530120    TRUE
# 7420   85    0.4705882   FALSE
# 7421   73    0.3287671   FALSE
# 7422   54    0.3703704   FALSE
# 7423  418    0.6961722    TRUE
# 7424  199    0.8190955    TRUE
# 7425   42    0.5000000   FALSE
# 7426  122    0.3114754   FALSE

# %% [markdown]
# - - -
#
# ## Dates and date-times
#
# In this final part, we combine what we've practised so far with `lubridate`, which gives us functionality to work with dates and date-times. Here, [Chapter 16](https://r4ds.had.co.nz/dates-and-times.html) of the book comes into play.
#
# **17. Find the right `lubridate` function to convert the following string to a `date` object!** This string is in the same format as the "Ddate" column of our coffee dataset, so knowing the conversion function will help us work with it.

# %%
ddate1 <- "8/21/13"  # a.k.a. 21st August, 2013

# %%
mdy(ddate1)  # mdy = month - day - year.
# Note that we don't have to specify if these are separated by slashes or hyphens or something else; lubridate figures that out for us.
# Out:
# [1] "2013-08-21"

# %% [markdown]
# **18. Modify the `coffee` dataset so that the "ddate" column contains a parsed "date" object instead of a string!** In the transformed dataset, "ddate" should now be a column of type `<date>` instead of `<chr>`.

# %%
(coffee <- mutate(coffee, ddate = mdy(ddate)))
# Out:
#       ddate      market  product           product_type sales profit expenses
# 1     2013-09-01 Central Decaf Irish Cream Coffee        90    36    37
# 2     2012-05-01 East    Decaf Espresso    Espresso     203    56    55
# 3     2013-01-01 West    Caffe Latte       Espresso     524   136    93
# 4     2012-08-01 West    Earl Grey         Tea          273    81    68
# 5     2013-12-01 West    Amaretto          Coffee       201    -3    68
# 6     2012-09-01 East    Lemon             Herbal Tea   171    26    73
# 7     2013-09-01 Central Caffe Mocha       Espresso     132    72    31
# 8     2013-02-01 Central Decaf Irish Cream Coffee       225   160    56
# 9     2012-10-01 South   Decaf Espresso    Espresso     108    37    42
# 10    2013-09-01 Central Decaf Irish Cream Coffee       208   105    43
# 11    2012-02-01 South   Caffe Latte       Espresso     117    46    22
# 12    2012-05-01 East    Lemon             Herbal Tea   214    48    59
# 13    2012-01-01 Central Decaf Irish Cream Coffee       316   163    64
# 14    2012-01-01 South   Decaf Irish Cream Coffee       112    66    24
# 15    2013-02-01 South   Decaf Irish Cream Coffee       130    68    43
# 16    2012-09-01 East    Lemon             Herbal Tea    84    -8    72
# 17    2012-01-01 East    Decaf Irish Cream Coffee       252    87    81
# 18    2012-08-01 South   Caffe Mocha       Espresso      49    23    17
# 19    2013-10-01 Central Lemon             Herbal Tea    67    18    17
# 20    2013-07-01 Central Decaf Irish Cream Coffee        70    24    22
# 21    2013-05-01 Central Lemon             Herbal Tea   114    41    43
# 22    2012-10-01 East    Mint              Herbal Tea   100     2    40
# 23    2012-02-01 Central Darjeeling        Tea          208    99    34
# 24    2013-09-01 East    Lemon             Herbal Tea   227   112    50
# 25    2013-02-01 South   Decaf Irish Cream Coffee        96    27    39
# 26    2012-10-01 West    Decaf Irish Cream Coffee       114    16    51
# 27    2013-02-01 South   Decaf Irish Cream Coffee        82    36    23
# 28    2012-07-01 West    Lemon             Herbal Tea   233    75    56
# 29    2012-02-01 West    Decaf Irish Cream Coffee       109     6    55
# 30    2012-12-01 Central Decaf Irish Cream Coffee       111    13    37
# ⋮     ⋮          ⋮       ⋮                 ⋮            ⋮     ⋮      ⋮
# 9971  2012-05-01 Central Earl Grey         Tea          259   103     45
# 9972  2012-10-01 South   Caffe Mocha       Espresso     215    81     59
# 9973  2013-06-01 East    Decaf Espresso    Espresso     100    12     33
# 9974  2013-09-01 East    Darjeeling        Tea           75    45     35
# 9975  2013-05-01 Central Decaf Irish Cream Coffee       132    51     42
# 9976  2013-05-01 Central Decaf Irish Cream Coffee        61    29     18
# 9977  2013-11-01 Central Decaf Irish Cream Coffee       536   388    103
# 9978  2013-08-01 East    Chamomile         Herbal Tea    74    20     20
# 9979  2013-02-01 East    Decaf Espresso    Espresso     124    65     32
# 9980  2012-10-01 East    Amaretto          Coffee       262    12     64
# 9981  2013-08-01 West    Chamomile         Herbal Tea    71     3     11
# 9982  2013-05-01 West    Decaf Irish Cream Coffee       125    31     43
# 9983  2012-12-01 Central Decaf Irish Cream Coffee       189    34     44
# 9984  2013-09-01 West    Decaf Irish Cream Coffee       139    28     41
# 9985  2013-08-01 West    Caffe Mocha       Espresso      78    19     29
# 9986  2013-09-01 East    Decaf Irish Cream Coffee       307   125     41
# 9987  2013-01-01 East    Mint              Herbal Tea   149    54     48
# 9988  2013-05-01 West    Decaf Irish Cream Coffee       180    40     45
# 9989  2012-11-01 South   Caffe Latte       Espresso      91    21     28
# 9990  2012-02-01 West    Amaretto          Coffee       124    24     51
# 9991  2012-11-01 East    Regular Espresso  Espresso      62    28     24
# 9992  2012-05-01 West    Caffe Mocha       Espresso      99    24     49
# 9993  2012-03-01 Central Decaf Irish Cream Coffee       104    20     34
# 9994  2013-05-01 West    Lemon             Herbal Tea   504   291    127
# 9995  2012-01-01 Central Decaf Irish Cream Coffee       310   163     36
# 9996  2012-02-01 Central Darjeeling        Tea          185    59     39
# 9997  2012-03-01 East    Darjeeling        Tea           88    17     36
# 9998  2013-08-01 Central Chamomile         Herbal Tea    61    21     21
# 9999  2012-04-01 East    Caffe Mocha       Espresso     124    38     84
# 10000 2012-05-01 West    Darjeeling        Tea          524   150     89
#       revenue margin      profit_above_avg
# 1      73      0.49315068 FALSE
# 2     111      0.50450450 FALSE
# 3     229      0.59388646  TRUE
# 4     149      0.54362416  TRUE
# 5      65     -0.04615385 FALSE
# 6      99      0.26262626 FALSE
# 7     103      0.69902913  TRUE
# 8     216      0.74074074  TRUE
# 9      79      0.46835443 FALSE
# 10    148      0.70945946  TRUE
# 11     68      0.67647059 FALSE
# 12    107      0.44859813 FALSE
# 13    227      0.71806167  TRUE
# 14     90      0.73333333  TRUE
# 15    111      0.61261261  TRUE
# 16     64     -0.12500000 FALSE
# 17    168      0.51785714  TRUE
# 18     40      0.57500000 FALSE
# 19     35      0.51428571 FALSE
# 20     46      0.52173913 FALSE
# 21     84      0.48809524 FALSE
# 22     42      0.04761905 FALSE
# 23    133      0.74436090  TRUE
# 24    162      0.69135802  TRUE
# 25     66      0.40909091 FALSE
# 26     67      0.23880597 FALSE
# 27     59      0.61016949 FALSE
# 28    131      0.57251908  TRUE
# 29     61      0.09836066 FALSE
# 30     50      0.26000000 FALSE
# ⋮     ⋮       ⋮           ⋮
# 9971  148     0.6959459    TRUE
# 9972  140     0.5785714    TRUE
# 9973   45     0.2666667   FALSE
# 9974   80     0.5625000   FALSE
# 9975   93     0.5483871   FALSE
# 9976   47     0.6170213   FALSE
# 9977  491     0.7902240    TRUE
# 9978   40     0.5000000   FALSE
# 9979   97     0.6701031    TRUE
# 9980   76     0.1578947   FALSE
# 9981   14     0.2142857   FALSE
# 9982   74     0.4189189   FALSE
# 9983   78     0.4358974   FALSE
# 9984   69     0.4057971   FALSE
# 9985   48     0.3958333   FALSE
# 9986  166     0.7530120    TRUE
# 9987  102     0.5294118   FALSE
# 9988   85     0.4705882   FALSE
# 9989   49     0.4285714   FALSE
# 9990   75     0.3200000   FALSE
# 9991   52     0.5384615   FALSE
# 9992   73     0.3287671   FALSE
# 9993   54     0.3703704   FALSE
# 9994  418     0.6961722    TRUE
# 9995  199     0.8190955    TRUE
# 9996   98     0.6020408   FALSE
# 9997   53     0.3207547   FALSE
# 9998   42     0.5000000   FALSE
# 9999  122     0.3114754   FALSE
# 10000 239     0.6276151    TRUE

# %% [markdown]
# **19. Select all _rows_ of the dataset where the _month_ is August.** Use your transformed dataset from the previous question.

# %%
filter(coffee, month(ddate) == 8)
# Out:
#      ddate      market  product           product_type sales profit expenses
# 1    2012-08-01 West    Earl Grey         Tea          273    81     68
# 2    2012-08-01 South   Caffe Mocha       Espresso      49    23     17
# 3    2012-08-01 West    Darjeeling        Tea          345   122     46
# 4    2013-08-01 South   Lemon             Herbal Tea    84    32     19
# 5    2012-08-01 South   Decaf Espresso    Espresso      78     0     34
# 6    2013-08-01 Central Decaf Irish Cream Coffee       350   214    105
# 7    2012-08-01 South   Caffe Latte       Espresso      48    10     15
# 8    2012-08-01 South   Lemon             Herbal Tea    82     8     22
# 9    2012-08-01 South   Caffe Mocha       Espresso     311   128     71
# 10   2013-08-01 Central Decaf Irish Cream Coffee        65     5     20
# 11   2012-08-01 Central Lemon             Herbal Tea   231    99     46
# 12   2013-08-01 East    Darjeeling        Tea           53     9     15
# 13   2012-08-01 East    Darjeeling        Tea           56    10     18
# 14   2012-08-01 South   Lemon             Herbal Tea    73    22     19
# 15   2013-08-01 Central Decaf Irish Cream Coffee       331   135     41
# 16   2012-08-01 Central Caffe Mocha       Espresso      57    11     19
# 17   2012-08-01 West    Mint              Herbal Tea   291    82     66
# 18   2013-08-01 West    Chamomile         Herbal Tea   108    17     24
# 19   2012-08-01 West    Chamomile         Herbal Tea   322   143    148
# 20   2012-08-01 West    Caffe Mocha       Espresso     516   105    108
# 21   2012-08-01 Central Lemon             Herbal Tea    76    23     41
# 22   2012-08-01 South   Caffe Latte       Espresso     309    83     62
# 23   2013-08-01 East    Decaf Irish Cream Coffee       333    85     72
# 24   2012-08-01 West    Decaf Irish Cream Coffee       125    24     69
# 25   2012-08-01 West    Caffe Mocha       Espresso     281    27    146
# 26   2012-08-01 South   Decaf Irish Cream Coffee       204    42     57
# 27   2013-08-01 Central Chamomile         Herbal Tea    59    -3     23
# 28   2012-08-01 Central Chamomile         Herbal Tea   318   113     47
# 29   2012-08-01 West    Chamomile         Herbal Tea   327   168    138
# 30   2012-08-01 West    Decaf Irish Cream Coffee       113    12     21
# ⋮    ⋮          ⋮       ⋮                 ⋮            ⋮     ⋮      ⋮
# 1290 2012-08-01 South   Decaf Irish Cream Coffee       323    84     64
# 1291 2012-08-01 West    Decaf Espresso    Espresso      92    21     36
# 1292 2013-08-01 South   Decaf Irish Cream Coffee       545   249    131
# 1293 2012-08-01 West    Lemon             Herbal Tea    86    26     45
# 1294 2012-08-01 West    Chamomile         Herbal Tea   315   175    156
# 1295 2013-08-01 Central Decaf Irish Cream Coffee        67    15     14
# 1296 2012-08-01 West    Lemon             Herbal Tea    90    29     47
# 1297 2012-08-01 West    Chamomile         Herbal Tea    71    19     22
# 1298 2012-08-01 East    Chamomile         Herbal Tea   235    89     45
# 1299 2012-08-01 West    Chamomile         Herbal Tea   239    13     62
# 1300 2012-08-01 South   Decaf Irish Cream Coffee        69    19     23
# 1301 2012-08-01 Central Decaf Irish Cream Coffee       285   175     45
# 1302 2013-08-01 Central Decaf Irish Cream Coffee       323   126     67
# 1303 2012-08-01 West    Lemon             Herbal Tea   511   212    103
# 1304 2012-08-01 Central Darjeeling        Tea           57    11     22
# 1305 2012-08-01 Central Decaf Irish Cream Coffee       215   120     45
# 1306 2012-08-01 East    Decaf Irish Cream Coffee       308   119     63
# 1307 2012-08-01 West    Decaf Irish Cream Coffee        59    15     21
# 1308 2013-08-01 East    Darjeeling        Tea           61    36     17
# 1309 2012-08-01 West    Decaf Irish Cream Coffee       174    42     67
# 1310 2012-08-01 West    Decaf Irish Cream Coffee       165    42     45
# 1311 2012-08-01 Central Caffe Mocha       Espresso     572   199    112
# 1312 2013-08-01 West    Darjeeling        Tea          506   194    112
# 1313 2012-08-01 South   Caffe Mocha       Espresso      76     8     18
# 1314 2013-08-01 South   Decaf Irish Cream Coffee       104     8     31
# 1315 2012-08-01 West    Decaf Irish Cream Coffee       244    30    166
# 1316 2013-08-01 East    Chamomile         Herbal Tea    74    20     20
# 1317 2013-08-01 West    Chamomile         Herbal Tea    71     3     11
# 1318 2013-08-01 West    Caffe Mocha       Espresso      78    19     29
# 1319 2013-08-01 Central Chamomile         Herbal Tea    61    21     21
#      revenue margin     profit_above_avg
# 1    149      0.5436242  TRUE
# 2     40      0.5750000 FALSE
# 3    168      0.7261905  TRUE
# 4     51      0.6274510 FALSE
# 5     34      0.0000000 FALSE
# 6    319      0.6708464  TRUE
# 7     25      0.4000000 FALSE
# 8     30      0.2666667 FALSE
# 9    199      0.6432161  TRUE
# 10    25      0.2000000 FALSE
# 11   145      0.6827586  TRUE
# 12    24      0.3750000 FALSE
# 13    28      0.3571429 FALSE
# 14    41      0.5365854 FALSE
# 15   176      0.7670455  TRUE
# 16    30      0.3666667 FALSE
# 17   148      0.5540541  TRUE
# 18    41      0.4146341 FALSE
# 19   291      0.4914089  TRUE
# 20   213      0.4929577  TRUE
# 21    64      0.3593750 FALSE
# 22   145      0.5724138  TRUE
# 23   157      0.5414013  TRUE
# 24    93      0.2580645 FALSE
# 25   173      0.1560694 FALSE
# 26    99      0.4242424 FALSE
# 27    20     -0.1500000 FALSE
# 28   160      0.7062500  TRUE
# 29   306      0.5490196  TRUE
# 30    33      0.3636364 FALSE
# ⋮    ⋮       ⋮          ⋮
# 1290 148     0.5675676   TRUE
# 1291  57     0.3684211  FALSE
# 1292 380     0.6552632   TRUE
# 1293  71     0.3661972  FALSE
# 1294 331     0.5287009   TRUE
# 1295  29     0.5172414  FALSE
# 1296  76     0.3815789  FALSE
# 1297  41     0.4634146  FALSE
# 1298 134     0.6641791   TRUE
# 1299  75     0.1733333  FALSE
# 1300  42     0.4523810  FALSE
# 1301 220     0.7954545   TRUE
# 1302 193     0.6528497   TRUE
# 1303 315     0.6730159   TRUE
# 1304  33     0.3333333  FALSE
# 1305 165     0.7272727   TRUE
# 1306 182     0.6538462   TRUE
# 1307  36     0.4166667  FALSE
# 1308  53     0.6792453  FALSE
# 1309 109     0.3853211  FALSE
# 1310  87     0.4827586  FALSE
# 1311 311     0.6398714   TRUE
# 1312 306     0.6339869   TRUE
# 1313  26     0.3076923  FALSE
# 1314  39     0.2051282  FALSE
# 1315 196     0.1530612  FALSE
# 1316  40     0.5000000  FALSE
# 1317  14     0.2142857  FALSE
# 1318  48     0.3958333  FALSE
# 1319  42     0.5000000  FALSE

# %% [markdown]
# **20. How many "ddate"s in the dataset fell on a Sunday, and how many rows do we have for these dates?** I'll give you the answer in table form below – produce a function pipeline that ultimately gives the same result:
#
# |   ddate    | count | wday   |
# |------------|-------|--------|
# | 2012-01-01 | 565   | Sunday |
# | 2012-04-01 | 434   | Sunday |
# | 2012-07-01 | 431   | Sunday |
# | 2013-09-01 | 410   | Sunday |
# | 2013-12-01 | 99    | Sunday |

# %%
coffee %>%
  group_by(ddate) %>%
  summarise(
      count = n(),
      wday = wday(unique(ddate), label = TRUE, abbr = FALSE),
  ) %>%
  filter(
      wday == "Sunday"
  )
# Out:
#   ddate      count wday
# 1 2012-01-01 565   Sunday
# 2 2012-04-01 434   Sunday
# 3 2012-07-01 431   Sunday
# 4 2013-09-01 410   Sunday
# 5 2013-12-01  99   Sunday

# %% [markdown]
# The "coffee chain" dataset doesn't contain any times or date-times, so we'll try to answer some "artificial" questions that deal with those for now. There will be more opportunities to practice working with times and date-times in the assignment (and potentially other exercises).
#
# **21. How many _seconds_ passed between the birth of _Queen Elizabeth II of the United Kingdom_ and _King Carl XVI Gustaf of Sweden_?** Wikipedia is very specific about the times that royals were born. Concretely, you can find that:
#
# - Queen Elizabeth II was born on April 21, 1926, at 2:40 a.m. GMT in London.
# - Carl XVI Gustaf was born on April 30, 1946, at 10:20 a.m. in Stockholm.
#
# Create date-time objects for the birth of these two monarchs (don't forget about time zones!) and compute the difference _in seconds_ between them!

# %%
(elizabeth <- dmy_hm("21-04-1926 02:40", tz="GMT"))
(carlgustaf <- dmy_hm("30-04-1946 10:20", tz="Europe/Stockholm"))
as.duration(carlgustaf - elizabeth)
# Out:
# [1] "1926-04-21 02:40:00 GMT"
# [1] "1946-04-30 10:20:00 CET"
# [1] "631953600s (~20.03 years)"

# %% [markdown]
# **22. How many seconds after 10:00:00 is it right now?** This is a use case for the `hms` package, which isn't explicitly described in the book, but is simple & useful enough that we can just take a brief look at its documentation. Check `?hms` or [the "hms" website](https://hms.tidyverse.org/) for a brief overview of the package, and use the `hms()`, `as_hms()`, and `now()` functions to answer the question.

# %%
as_hms(now()) - hms(0, 0, 10)
# Out:
# Time difference of 7903.683 secs
